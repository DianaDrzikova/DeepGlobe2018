# %% [markdown]
# ## Install requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Download dataset

# %%
# !python download_dataset.py

# %% [markdown]
# ## Train

# %%
# !python train.py --config congif.yaml

# %% [markdown]
# ## Evaluation

# %%
# !python evaluate.py --config congif.yaml
